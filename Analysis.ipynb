# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/minor project../presentation/result.csv")
df.head()
# Out:
#    Unnamed: 0 CountryName CountryCode  \
# 0           0   Australia         AUS
# 1           1   Australia         AUS
# 2           2   Australia         AUS
# 3           3   Australia         AUS
# 4           4   Australia         AUS
#
#                                        IndicatorName   IndicatorCode  Year  \
# 0  Maternal mortality ratio (modeled estimate, pe...     SH.STA.MMRT  2015
# 1            Time required to get electricity (days)     IC.ELC.TIME  2015
# 2                           Bird species, threatened  EN.BIR.THRD.NO  2015
# 3                           Fish species, threatened  EN.FSH.THRD.NO  2015
# 4                         Mammal species, threatened  EN.MAM.THRD.NO  2015
#
#    Value     IndicatorGroup        CountryGroup CountryStatus
# 0    6.0  Aid effectiveness  EastAsia & Pacific     Developed
# 1   75.0    Energy & Mining  EastAsia & Pacific     Developed
# 2   50.0        Environment  EastAsia & Pacific     Developed
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0   Australia         AUS  Maternal mortality ratio (modeled estimate, pe...
# 1   Australia         AUS            Time required to get electricity (days)
# 2   Australia         AUS                           Bird species, threatened
# 3   Australia         AUS                           Fish species, threatened
# 4   Australia         AUS                         Mammal species, threatened
#
#     IndicatorCode  Year  Value     IndicatorGroup        CountryGroup  \
# 0     SH.STA.MMRT  2015    6.0  Aid effectiveness  EastAsia & Pacific
# 1     IC.ELC.TIME  2015   75.0    Energy & Mining  EastAsia & Pacific
# 2  EN.BIR.THRD.NO  2015   50.0        Environment  EastAsia & Pacific
# 3  EN.FSH.THRD.NO  2015  111.0        Environment  EastAsia & Pacific
# 4  EN.MAM.THRD.NO  2015   56.0        Environment  EastAsia & Pacific
#
#   CountryStatus
# 0     Developed
# 1     Developed
# 2     Developed
# ...

# %%
devdf=df.loc[df['CountryStatus']=='Developed']

# %%
devdf['IndicatorGroup'].value_counts()
# Out:
# Private Sector        210
# Environment           140
# Financial Sector      121
# Health                105
# Gender                 70
# Public Sector          70
# Aid effectiveness      35
# Energy & Mining        35
# Social Development     35
# Name: IndicatorGroup, dtype: int64

# %%
devdf['CountryName'].unique().shape
# Out:
# (34,)

# %%
df.drop(['Year'],axis=1,inplace=True)
devdf.drop(['Year'],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
devdf.drop(['CountryCode','IndicatorCode'],inplace=True,axis=1)
devdf.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#   CountryName                                      IndicatorName  Value  \
# 0   Australia  Maternal mortality ratio (modeled estimate, pe...    6.0
# 1   Australia            Time required to get electricity (days)   75.0
# 2   Australia                           Bird species, threatened   50.0
# 3   Australia                           Fish species, threatened  111.0
# 4   Australia                         Mammal species, threatened   56.0
#
#       IndicatorGroup        CountryGroup CountryStatus
# 0  Aid effectiveness  EastAsia & Pacific     Developed
# 1    Energy & Mining  EastAsia & Pacific     Developed
# 2        Environment  EastAsia & Pacific     Developed
# ...

# %%
import seaborn as sns

# %%
sns.countplot(df['CountryStatus'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #Analysing all the indicators one by one for different status

# %%
df.IndicatorName.unique().shape
# Out:
# (16,)

# %%
Indicator_values=list(df.loc[df['CountryStatus']=='Developed']['IndicatorGroup'].unique())
Indicator_values
# Out:
# ['Aid effectiveness',
#  'Energy & Mining',
#  'Environment',
#  'Financial Sector',
#  'Gender',
#  'Health',
#  'Private Sector',
#  'Public Sector',
#  'Social Development']

# %%
import numpy as np

# %%
Status=list(df['CountryStatus'].unique())

# %% [markdown]
# #DEVELOPED

# %%
import matplotlib.pyplot as plt
aid=df.loc[(df['CountryStatus']=='Developed')]
plt.figure(figsize=(15,9))
sns.barplot(aid['CountryStatus'],aid['Value'],hue=df['IndicatorName'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #Developing

# %%
aid=df.loc[(df['CountryStatus']=='Developing')]
plt.figure(figsize=(15,7))
sns.barplot(aid['CountryStatus'],aid['Value'],hue=df['IndicatorName'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #UNDERDEVELOPED

# %%
aid=df.loc[(df['CountryStatus']=='UnderDeveloped')]
plt.figure(figsize=(15,7))
sns.barplot(aid['CountryStatus'],aid['Value'],hue=df['IndicatorName'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #ENVIRONMENT:-

# %%
aid=df.loc[df['IndicatorGroup']=='Environment']
plt.figure(figsize=(10,7))
sns.set_style('whitegrid')
sns.barplot(aid['IndicatorName'],aid['Value'],hue=df['CountryStatus'])
plt.xticks (rotation=90 )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([0, 1, 2, 3]), <a list of 4 Text major ticklabel objects>)

# %% [markdown]
# #PRIVATE SECTOR

# %%
aid=df.loc[df['IndicatorGroup']=='Private Sector']
plt.figure(figsize=(10,7))
sns.set_style('whitegrid')
sns.barplot(aid['IndicatorName'],aid['Value'],hue=df['CountryStatus'])
plt.xticks (rotation=90 )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# #FINANCIAL SECTOR

# %%
aid=df.loc[df['IndicatorGroup']=='Financial Sector']
plt.figure(figsize=(10,7))
sns.set_style('whitegrid')
sns.barplot(aid['IndicatorName'],aid['Value'],hue=df['CountryStatus'])
plt.xticks (rotation=90 )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([0, 1, 2, 3]), <a list of 4 Text major ticklabel objects>)

# %% [markdown]
# #SOCIAL DEVELOPMENT

# %%
aid=df.loc[df['IndicatorGroup']=='Social Development']
plt.figure(figsize=(5,8))
sns.set_style('whitegrid')
sns.barplot(aid['IndicatorName'],aid['Value'],hue=df['CountryStatus'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #PUBLIC SECTOR

# %%
aid=df.loc[df['IndicatorGroup']=='Public Sector']
plt.figure(figsize=(12,7))
sns.set_style('whitegrid')
sns.barplot(aid['IndicatorName'],aid['Value'],hue=df['CountryStatus'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #AID EFFECTIVENESS

# %%
aid=df.loc[df['IndicatorGroup']=='Aid effectiveness']
plt.figure(figsize=(5,7))
sns.set_style('whitegrid')
sns.barplot(aid['IndicatorName'],aid['Value'],hue=df['CountryStatus'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #ENERGY AND MINING

# %%
aid=df.loc[df['IndicatorGroup']=='Energy & Mining']
plt.figure(figsize=(5,7))
sns.set_style('whitegrid')
sns.barplot(aid['IndicatorName'],aid['Value'],hue=df['CountryStatus'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #GENDER

# %%
aid=df.loc[df['IndicatorGroup']=='Gender']
plt.figure(figsize=(14,7))
sns.set_style('whitegrid')
sns.barplot(aid['IndicatorName'],aid['Value'],hue=df['CountryStatus'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #HEALTH

# %%
aid=df.loc[df['IndicatorGroup']=='Health']
plt.figure(figsize=(10,7))
sns.set_style('whitegrid')
sns.barplot(aid['IndicatorName'],aid['Value'],hue=df['CountryStatus'])
plt.xticks (rotation=90 )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)
